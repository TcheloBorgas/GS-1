# %%
#━━━━━━━━━❮Bibliotecas❯━━━━━━━━━
from datetime import datetime
#━━━━━━━━━━━━━━❮◆❯━━━━━━━━━━━━━━

# %%
class Produto:
    def __init__(self, nome, data_validade):
        self.nome = nome
        self.data_validade = data_validade

class Organizacao:
    def __init__(self, nome, endereco):
        self.nome = nome
        self.endereco = endereco
        self.produtos_recebidos = []

    def receber_produto(self, produto):
        self.produtos_recebidos.append(produto)

class Logistica:
    def __init__(self):
        self.produtos = []
        self.organizacoes = []

    def adicionar_produto(self, produto):
        self.produtos.append(produto)

    def registrar_organizacao(self, organizacao):
        self.organizacoes.append(organizacao)

    def verificar_vencimentos(self):
        for produto in self.produtos:
            data_validade = datetime.strptime(produto.data_validade, '%d/%m/%Y')
            if data_validade.date() <= datetime.now().date():
                self.agendar_coleta(produto)
                print('━━━━━━━━━━━━━━❮◆❯━━━━━━━━━━━━━━')
                print(f'O produto {produto.nome} está vencendo ou já venceu.')
                print('━━━━━━━━━━━━━━❮◆❯━━━━━━━━━━━━━━')
                print('')


    def agendar_coleta(self, produto):
        # Escolhe a primeira organização da lista para simplificar
        organizacao = self.organizacoes[0]
        organizacao.receber_produto(produto)
        print('━━━━━━━━━━━━━━❮◆❯━━━━━━━━━━━━━━')
        print(f"Coleta agendada: {produto.nome} para {organizacao.nome}")
        print('━━━━━━━━━━━━━━❮◆❯━━━━━━━━━━━━━━')
        print('')

class InterfaceUsuario:
    def __init__(self, logistica):
        self.logistica = logistica

    def iniciar(self):
        while True:
            print('━━━━━━━━━━━━━━❮◆❯━━━━━━━━━━━━━━')
            print("\n1 - Adicionar produto")
            print("2 - Registrar organização")
            print("3 - Verificar vencimentos")
            print("4 - Sair")
            print('━━━━━━━━━━━━━━❮◆❯━━━━━━━━━━━━━━')
            print('')

            opcao = input("\nEscolha uma opção: ")

            if opcao == '1':
                self.adicionar_produto()
            elif opcao == '2':
                self.registrar_organizacao()
            elif opcao == '3':
                self.logistica.verificar_vencimentos()
            elif opcao == '4':
                break
            else:
                print("Opção inválida!")
                print('')

    def adicionar_produto(self):
        nome_produto = input("Nome do produto: ")
        data_validade = input("Data de validade (formato dd/mm/aaaa): ")
        produto = Produto(nome_produto, data_validade)
        self.logistica.adicionar_produto(produto)
        print('━━━━━━━━━━━━━━❮◆❯━━━━━━━━━━━━━━')
        print(f"Produto {nome_produto} adicionado com sucesso!")
        print('━━━━━━━━━━━━━━❮◆❯━━━━━━━━━━━━━━')
        print('')

    def registrar_organizacao(self):
        nome = input("Nome da organização: ")
        endereco = input("Endereço da organização: ")
        organizacao = Organizacao(nome, endereco)
        self.logistica.registrar_organizacao(organizacao)
        print('━━━━━━━━━━━━━━❮◆❯━━━━━━━━━━━━━━')
        print(f"Organização {nome} registrada com sucesso!")
        print('━━━━━━━━━━━━━━❮◆❯━━━━━━━━━━━━━━')
        print('')

# %%
#━━━━━━━━━━━━❮Inicio❯━━━━━━━━━━━━
logistica = Logistica()
interface_usuario = InterfaceUsuario(logistica)
interface_usuario.iniciar()
#━━━━━━━━━━━━━━❮◆❯━━━━━━━━━━━━━━
# Out:
# 1 - Adicionar produto
# 2 - Registrar organização
# 3 - Verificar vencimentos
# 4 - Sair
# Produto chocolate adicionado com sucesso!
#
# 1 - Adicionar produto
# 2 - Registrar organização
# 3 - Verificar vencimentos
# 4 - Sair
# Organização OMS registrada com sucesso!
#
# 1 - Adicionar produto
# 2 - Registrar organização
# 3 - Verificar vencimentos
# 4 - Sair
# Coleta agendada: chocolate para OMS
# O produto chocolate está vencendo ou já venceu.
#
# 1 - Adicionar produto
# 2 - Registrar organização
# 3 - Verificar vencimentos
# 4 - Sair
